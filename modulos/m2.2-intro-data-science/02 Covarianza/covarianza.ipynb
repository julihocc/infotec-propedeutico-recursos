# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
noise = np.random.normal(0, 1, size =100)
drift = 2
y = drift * x + noise

plt.plot(x, y)
plt.show()

# %%
# Calcular la media de X
x_mean = np.mean(x)

# Calcular la media de Y
y_mean = np.mean(y)

# Calcular la desviación de cada dato de su media correspondiente
x_dev = x - x_mean
y_dev = y - y_mean

# Multiplicar cada desviación de X por la desviación correspondiente de Y
cov_xy = x_dev * y_dev

# Promediar los productos calculados
cov = np.mean(cov_xy)

print(cov)
# Out:
# 16.68021262230923

# %%
cov_muestra = np.cov(x, y)

cov_muestra
# Out:
# array([[ 8.58755909, 16.84869962],
#        [16.84869962, 34.18935021]])

# %%
np.cov(x, y, ddof = 1)
# Out:
# array([[ 8.58755909, 16.84869962],
#        [16.84869962, 34.18935021]])

# %%
cov_poblacion = np.cov(x, y, ddof = 0)
cov_poblacion
# Out:
# array([[ 8.5016835 , 16.68021262],
#        [16.68021262, 33.84745671]])
