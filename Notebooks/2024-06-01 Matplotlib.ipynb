# %% [markdown]
# # Variables Aletorias
#
# ## Ejemplo 1: Distribución normal

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar 1000 valores aleatorios con distribución normal
np.random.seed(123)
mu =  26_860
sigma = 10_000
n = 1000
s = np.random.normal(mu, sigma, n)
np.mean(s), np.std(s)
# Out:
# (26464.358639192084, 10007.875375162334)

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
campana_gaussiana = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(- (bins - mu)**2 / (2 * sigma**2))
plt.plot(bins, campana_gaussiana)
plt.show()

# %%
# Ejemplo 2: Distribución binomial

n = 10
p = 0.5
s = np.random.binomial(n, p, 1000)

bins = np.arange(0, 12) - 0.5

# Histograma
count, bins, ignored = plt.hist(s, bins, density=True)
plt.show()

# %%
dias = np.arange(1,365+1)
ventas = np.random.normal(1000, 100, size=365)
# plt.plot(dias, ventas)
plt.scatter(dias, ventas)
plt.show()
